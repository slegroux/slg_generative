# %% [raw]
# ---
# description: Example of datasets to train generative models on
# output-file: data.datasets.html
# title: Datasets
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(ImageDataset)
# Out:
# ---
#
# [source](https://github.com/slegroux/slg_generative/blob/main/slg_generative/data/datasets.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### ImageDataset
#
# >      ImageDataset ()
#
# Base class for image datasets providing visualization of (image, label) samples

# %%
#| echo: false
#| output: asis
show_doc(MnistDataset)
# Out:
# ---
#
# [source](https://github.com/slegroux/slg_generative/blob/main/slg_generative/data/datasets.py#L28){target="_blank" style="float:right; font-size:smaller"}
#
# ### MnistDataset
#
# >      MnistDataset (data_root:str='./data')
#
# MNIST digit dataset
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | data_root | str | ./data | Path to data root folder |

# %%
ds = MnistDataset('~/Data')
print(f"Number of samples in the dataset: {len(ds)}")
X,y = ds[0]
print(f"Shape of image: {X.shape}, corresponding digit: {int(y)}")
print(f"types: {X.type()}, {y.type()}")

ds.show(0)
# Out:
# Number of samples in the dataset: 60000
# Shape of image: torch.Size([784]), corresponding digit: 5
# types: torch.FloatTensor, torch.LongTensor

# %%
#| echo: false
#| output: asis
show_doc(FashionMnistDataset)
# Out:
# ---
#
# [source](https://github.com/slegroux/slg_generative/blob/main/slg_generative/data/datasets.py#L48){target="_blank" style="float:right; font-size:smaller"}
#
# ### FashionMnistDataset
#
# >      FashionMnistDataset (csv_file:str)
#
# Fashion MNIST Dataset
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | csv_file | str | Path to csv data file |

# %%
map_labels = {
  "0": "T-shirt/top", "1": "Trouser", "2": "Pullover", "3": "Dress",
  "4": "Coat", "5": "Sandal", "6": "Shirt", "7": "Sneaker", "8": "Bag",
  "9": "Ankle boot"
}

ds = FashionMnistDataset(csv_file="~/Data/fashion-mnist/fashion-mnist_train.csv")
print(f"Number of samples in the dataset: {len(ds)}")
X,y = ds[0]

print(f"Shape of image: {X.shape}, corresponding label: {map_labels[str(int(y))]}")
ds.show(0)

dl = torch.utils.data.DataLoader(ds, batch_size=128, shuffle=True)

X, y = next(iter(dl))
print(f"types of batch content: {X.type()}, {y.type()}")
# Out:
# Number of samples in the dataset: 60000
# Shape of image: torch.Size([784]), corresponding label: Pullover
# types of batch content: torch.FloatTensor, torch.LongTensor
