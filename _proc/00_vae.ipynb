# %% [raw]
# ---
# description: implements simple version of Variational AutoEncoder for educational
#   purposes
# output-file: vae.html
# title: vae
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# ### foo
#
# >      foo ()

# %%
#| echo: false
#| output: asis
show_doc(test)
# Out:
# ---
#
# ### test
#
# >      test (a:float, b:float)
#
# _summary_
#
# Args:
#     a (float): _description_
#     b (float): _description_
#
# Returns:
#     _type_: _description_
