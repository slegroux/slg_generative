# %% [raw]
# ---
# description: implements simple version of Variational AutoEncoder (VAE) for educational
#   purposes
# output-file: models.vae.html
# title: VAE Model
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(AEEncoder)
# Out:
# ---
#
# [source](https://github.com/slegroux/slg_generative/blob/main/slg_generative/models/vae.py#L27){target="_blank" style="float:right; font-size:smaller"}
#
# ### AEEncoder
#
# >      AEEncoder (input_dim:int=784, hidden_dim:int=512, latent_dim:int=2)
#
# Simple AE Encoder
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | input_dim | int | 784 | Input dimension |
# | hidden_dim | int | 512 | Hidden dimension |
# | latent_dim | int | 2 | Latent dimension |

# %%
ds = FashionMnistDataset("~/Data/fashion-mnist/fashion-mnist_train.csv")
dl = torch.utils.data.DataLoader(ds, batch_size=128, shuffle=True)
X, y = next(iter(dl))
e = AEEncoder(input_dim=784, hidden_dim=512, latent_dim=2)
ee = e(X)
print(f"latent output shape {ee.shape}, {ee.type()}")
# Out:
# latent output shape torch.Size([128, 2]), torch.FloatTensor

# %%
#| echo: false
#| output: asis
show_doc(AEDecoder)
# Out:
# ---
#
# [source](https://github.com/slegroux/slg_generative/blob/main/slg_generative/models/vae.py#L48){target="_blank" style="float:right; font-size:smaller"}
#
# ### AEDecoder
#
# >      AEDecoder (latent_dim=2, hidden_dim=512, output_dim=784)
#
# Decoder
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | latent_dim | int | 2 | Latent dimension |
# | hidden_dim | int | 512 | Hidden dimension |
# | output_dim | int | 784 | Output dimension |

# %%
d = AEDecoder(latent_dim=2, hidden_dim=512, output_dim=784)
dd = d(ee)
print(dd.shape)
# Out:
# torch.Size([128, 784])

# %%
#| echo: false
#| output: asis
show_doc(AutoEncoder)
# Out:
# ---
#
# [source](https://github.com/slegroux/slg_generative/blob/main/slg_generative/models/vae.py#L68){target="_blank" style="float:right; font-size:smaller"}
#
# ### AutoEncoder
#
# >      AutoEncoder (input_dim=784, hidden_dim=512, latent_dim=2)
#
# autoencoder
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | input_dim | int | 784 | Output dimension |
# | hidden_dim | int | 512 | Hidden dimension |
# | latent_dim | int | 2 | Latent dimension |

# %%
ae = AutoEncoder(input_dim=784, hidden_dim=512, latent_dim=2)
out = ae(X)
print(out.shape)
# Out:
# torch.Size([128, 784])
